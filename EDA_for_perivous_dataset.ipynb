# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv("/content/previous_application.csv")

# %%
data.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
# 3     2819243      176158         Cash loans    47041.335         450000.0
# 4     1784265      202054         Cash loans    31924.395         337500.0
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0               0.0          17145.0                   SATURDAY
# 1    679671.0               NaN         607500.0                   THURSDAY
# 2    136444.5               NaN         112500.0                    TUESDAY
# 3    470790.0               NaN         450000.0                     MONDAY
# 4    404055.0               NaN         337500.0                   THURSDAY
#
#    HOUR_APPR_PROCESS_START FLAG_LAST_APPL_PER_CONTRACT  \
# ...

# %% [markdown]
# # Heat Map

# %%
corr_matrix = data.corr(numeric_only=True)

# %%
plt.figure(figsize=(15,10))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Between Numeric Features")
plt.show()

# %% [markdown]
# # vertical bar char

# %%
# for NAME_YIELD_GROUP

x = data['NAME_YIELD_GROUP'].value_counts(sort=False).index
y = data['NAME_YIELD_GROUP'].value_counts(sort=False)

plt.bar(x, y)

plt.xlabel('NAME_YIELD_GROUP')
plt.ylabel('count')

plt.show()

# %%
# for CHANNEL_TYPE


x = data['CHANNEL_TYPE'].value_counts(sort=False).index
y = data['CHANNEL_TYPE'].value_counts(sort=False)

plt.bar(x, y)

plt.xlabel('CHANNEL_TYPE')
plt.ylabel('count')

plt.xticks(rotation=90)
plt.show()

# %%
# for PRODUCT_COMBINATION


x = data['PRODUCT_COMBINATION'].value_counts(sort=False).index
y = data['PRODUCT_COMBINATION'].value_counts(sort=False)

plt.bar(x, y)

plt.xlabel('PRODUCT_COMBINATION')
plt.ylabel('count')

plt.xticks(rotation=90)
plt.show()

# %%
# for NAME_SELLER_INDUSTRY



x = data['NAME_SELLER_INDUSTRY'].value_counts(sort=False).index
y = data['NAME_SELLER_INDUSTRY'].value_counts(sort=False)

plt.bar(x, y)

plt.xlabel('NAME_SELLER_INDUSTRY')
plt.ylabel('count')

plt.xticks(rotation=90)
plt.show()

# %%
# for NAME_CONTRACT_TYPE



x = data['NAME_CONTRACT_TYPE'].value_counts(sort=False).index
y = data['NAME_CONTRACT_TYPE'].value_counts(sort=False)

plt.bar(x, y)

plt.xlabel('NAME_CONTRACT_TYPE')
plt.ylabel('count')

plt.xticks(rotation=90)
plt.show()

# %%
# for WEEKDAY_APPR_PROCESS_START


x = data['WEEKDAY_APPR_PROCESS_START'].value_counts(sort=False).index
y = data['WEEKDAY_APPR_PROCESS_START'].value_counts(sort=False)

plt.bar(x, y)

plt.xlabel('WEEKDAY_APPR_PROCESS_START')
plt.ylabel('count')

plt.xticks(rotation=90)
plt.show()

# %%
# for NAME_CONTRACT_STATUS


x = data['NAME_CONTRACT_STATUS'].value_counts(sort=False).index
y = data['NAME_CONTRACT_STATUS'].value_counts(sort=False)

plt.bar(x, y)

plt.xlabel('NAME_CONTRACT_STATUS')
plt.ylabel('count')

plt.xticks(rotation=90)
plt.show()

# %%
# for NAME_PAYMENT_TYPE


x = data['NAME_PAYMENT_TYPE'].value_counts(sort=False).index
y = data['NAME_PAYMENT_TYPE'].value_counts(sort=False)

plt.bar(x, y)

plt.xlabel('NAME_PAYMENT_TYPE')
plt.ylabel('count')

plt.xticks(rotation=90)
plt.show()

# %%
# for CODE_REJECT_REASON


x = data['CODE_REJECT_REASON'].value_counts(sort=False).index
y = data['CODE_REJECT_REASON'].value_counts(sort=False)

plt.bar(x, y)

plt.xlabel('CODE_REJECT_REASON')
plt.ylabel('count')

plt.xticks(rotation=90)
plt.show()

# %%
# for NAME_TYPE_SUITE


x = data['NAME_TYPE_SUITE'].value_counts(sort=False).index
y = data['NAME_TYPE_SUITE'].value_counts(sort=False)

plt.bar(x, y)

plt.xlabel('NAME_TYPE_SUITE')
plt.ylabel('count')

plt.xticks(rotation=90)
plt.show()

# %%
# for NAME_CLIENT_TYPE


x = data['NAME_CLIENT_TYPE'].value_counts(sort=False).index
y = data['NAME_CLIENT_TYPE'].value_counts(sort=False)

plt.bar(x, y)

plt.xlabel('NAME_CLIENT_TYPE')
plt.ylabel('count')

plt.xticks(rotation=90)
plt.show()

# %%
# for NAME_GOODS_CATEGORY


x = data['NAME_GOODS_CATEGORY'].value_counts(sort=False).index
y = data['NAME_GOODS_CATEGORY'].value_counts(sort=False)

plt.bar(x, y)

plt.xlabel('NAME_GOODS_CATEGORY')
plt.ylabel('count')

plt.xticks(rotation=90)
plt.show()

# %%
# for NAME_PORTFOLIO


x = data['NAME_PORTFOLIO'].value_counts(sort=False).index
y = data['NAME_PORTFOLIO'].value_counts(sort=False)

plt.bar(x, y)

plt.xlabel('NAME_PORTFOLIO')
plt.ylabel('count')

plt.xticks(rotation=90)
plt.show()

# %%
# for NAME_PRODUCT_TYPE


x = data['NAME_PRODUCT_TYPE'].value_counts(sort=False).index
y = data['NAME_PRODUCT_TYPE'].value_counts(sort=False)

plt.bar(x, y)

plt.xlabel('NAME_PRODUCT_TYPE')
plt.ylabel('count')

plt.xticks(rotation=90)
plt.show()

# %%
# for NAME_SELLER_INDUSTRY

x = data['NAME_SELLER_INDUSTRY'].value_counts(sort=False).index
y = data['NAME_SELLER_INDUSTRY'].value_counts(sort=False)

plt.bar(x, y)

plt.xlabel('NAME_SELLER_INDUSTRY')
plt.ylabel('count')

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Scater plot

# %%
plt.scatter(data = data, x = 'NFLAG_INSURED_ON_APPROVAL', y = 'AMT_ANNUITY');
plt.xlabel('NFLAG_INSURED_ON_APPROVAL');
plt.ylabel('AMT_ANNUITY');

# %%
plt.scatter(data = data, x = 'AMT_APPLICATION', y = 'AMT_GOODS_PRICE');
plt.xlabel('AMT_APPLICATION');
plt.ylabel('AMT_GOODS_PRICE');

# %%
plt.scatter(data = data, x = 'AMT_CREDIT', y = 'DAYS_FIRST_DUE');
plt.xlabel('AMT_CREDIT');
plt.ylabel('DAYS_FIRST_DUE');

# %%
plt.scatter(data = data, x = 'HOUR_APPR_PROCESS_START', y = 'DAYS_LAST_DUE');
plt.xlabel('HOUR_APPR_PROCESS_START');
plt.ylabel('DAYS_LAST_DUE');

# %%
plt.scatter(data = data, x = 'AMT_ANNUITY', y = 'AMT_GOODS_PRICE');
plt.xlabel('AMT_ANNUITY');
plt.ylabel('AMT_GOODS_PRICE');

# %%
plt.scatter(data = data, x = 'AMT_ANNUITY', y = 'AMT_APPLICATION');
plt.xlabel('AMT_ANNUITY');
plt.ylabel('AMT_APPLICATION');

# %%
plt.scatter(data = data, x = 'AMT_APPLICATION', y = 'CNT_PAYMENT');
plt.xlabel('AMT_APPLICATION');
plt.ylabel('CNT_PAYMENT');

# %%
plt.scatter(data = data, x = 'AMT_ANNUITY', y = 'CNT_PAYMENT');
plt.xlabel('AMT_ANNUITY');
plt.ylabel('CNT_PAYMENT');

# %%
plt.scatter(data = data, x = 'DAYS_LAST_DUE', y = 'RATE_INTEREST_PRIVILEGED');
plt.xlabel('DAYS_LAST_DUE');
plt.ylabel('RATE_INTEREST_PRIVILEGED');

# %%
plt.scatter(data = data, x = 'RATE_DOWN_PAYMENT', y = 'RATE_INTEREST_PRIVILEGED');
plt.xlabel('RATE_DOWN_PAYMENT');
plt.ylabel('RATE_INTEREST_PRIVILEGED');
